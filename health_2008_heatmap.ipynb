# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
from matplotlib import rc
from sklearn.model_selection import train_test_split

# 주피터 노트북 한글 설정
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# Load datasets
health = pd.read_csv('./data/NHIS_OPEN_GJ_2008.CSV', encoding='euc-kr')
health = health.iloc[:, 2:-1]

# 결측치행 제거
health = health.dropna()
print(health.head())
# Out:
#     성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 3      2            1    41        145          50    71    0.9    0.9    1.0
# 24     2            1    26        150          40    62    0.8    0.6    1.0
# 37     2            1    47        150          45    57    1.2    1.2    1.0
# 39     2            1    44        150          45    61    1.2    1.2    1.0
# 41     2            1    28        150          45    67    0.7    0.2    1.0
#
#     청력(우)  ...  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 3     1.0  ...        15.0     17   1.0   0.0          1      0.0    0.0
# 24    1.0  ...        11.0      8   1.0   0.0          1      0.0    0.0
# 37    1.0  ...        10.0     15   1.0   0.0          1      0.0    0.0
# 39    1.0  ...         9.0     10   1.0   0.0          1      1.0    0.0
# 41    1.0  ...        13.0      9   1.0   0.0          1      0.0    1.0
#
#     치아마모증유무  제3대구치(사랑니)이상   치석
# 3       0.0           0.0  0.0
# 24      0.0           0.0  1.0
# 37      0.0           1.0  0.0
# 39      0.0           0.0  1.0
# 41      0.0           0.0  1.0
#
# [5 rows x 27 columns]

# %%
correlation = health.corr()

fig = plt.subplots(figsize=(25,25))
sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap=sns.diverging_palette(20, 220, n=200))
